# %%
import os
import numpy as np
import pandas as pd

import wordcloud
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud

import nltk
from nltk.probability import FreqDist

# %%
os.listdir()
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'Data Analysis (Part 1).ipynb',
#  'Data Collection.ipynb',
#  'Data Preprocessing (Part 1).ipynb',
#  'Data Preprocessing (Part 2).ipynb',
#  'preprocessed_data (part 1).csv',
#  'preprocessed_data (part 2).csv',
#  'raw_data.csv',
#  'README.md']

# %%
data=pd.read_csv("preprocessed_data (part 2).csv")
data
# Out:
#                   Album                                             Lyrics
# 0  Doo-Wops & Hooligans  easy come easy go live oh take take take never...
# 1    Unorthodox Jukebox  spend money big old fancy car brighteyed honey...
# 2                  XX4K  tonight want take higher throw hand sky let u ...

# %%
albums=data["Album"].tolist()
lyrics=data["Lyrics"].tolist()
labels= [[x, y] for x, y in zip(albums, lyrics)]

wordcloud = WordCloud()

def wordCloud(album,label):
    i=Counter(album.split())
    df=pd.DataFrame.from_dict(i, orient='index').reset_index()
    z = {}
    for x, y in df.values:
        z[x] = y
    wordcloud.generate_from_frequencies(frequencies=z)
    plt.figure()
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.figtext(0.5, 0.85,label,horizontalalignment="center",fontsize=15)
    plt.show()

[wordCloud(i,j) for j,i in labels]
# Out:
# [None, None, None]

# %% [markdown]
# I have to check whether the *preprocess* function I previously created indeed lemmatized the words; "going" in *XX4K* should have been easily decomposed to "go." Nonetheless, it's a minor issue that I'm not very concerned with. In that regard, note that there are certain words (yeah, oh, I) that I have to remove to further decrease random noise in my data.
#
# Let's temporarily combine all three albums and see the top 25 most frequent words:

# %%
count=Counter(" ".join(lyrics).split())
x=pd.DataFrame.from_dict(count, orient='index').reset_index()
x.columns=["Word","Frequency"]
x=x.sort_values("Frequency",ascending=False)
x=x.iloc[0:25,:].reset_index(drop=True)
x
# Out:
#         Word  Frequency
# 0       yeah        183
# 1          I        133
# 2       baby        120
# 3        got        113
# 4       like         96
# 5         oh         93
# 6       girl         90
# 7       know         87
# 8         go         66
# 9       take         57
# 10      show         57
# 11      want         56
# 12       get         51
# 13     going         48
# 14      make         48
# 15       let         46
# 16      give         42
# 17      tell         42
# 18         u         41
# 19       say         41
# 20       one         41
# 21  straight         41
# 22       ooh         40
# 23      feel         40
# 24     would         39
